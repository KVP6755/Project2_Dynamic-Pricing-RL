# %% [markdown]
# ## Business Metrics Analysis
#
# ### Week 4 – Member 2
#
# **Author:** Shilpa S Nair
#
# This notebook analyzes the business Key Performance Indicators (KPIs) generated from the dynamic pricing environment.

# %%
from business_metrics import BusinessMetrics

# %%
metrics = BusinessMetrics()
# Out:
# {'prices': [4000, 4500, 5000, 5500, 6000], 'bookings': [18, 25, 30, 20, 12], 'total_requests': [20, 30, 35, 25, 15]}

# %%
print("Pricing Levels")
print(metrics.prices)

print("\nBookings")
print(metrics.bookings)

print("\nBooking Requests")
print(metrics.total_requests)
# Out:
# Pricing Levels
# [4000, 4500, 5000, 5500, 6000]
#
# Bookings
# [18, 25, 30, 20, 12]
#
# Booking Requests
# [20, 30, 35, 25, 15]

# %% [markdown]
# ### Total Revenue

# %%
total_revenue = metrics.calculate_total_revenue()

print("Total Revenue")
print(f"₹ {total_revenue:,}")
# Out:
# Total Revenue
# ₹ 516,500

# %% [markdown]
# ### Average Revenue

# %%
average_revenue = metrics.calculate_average_revenue()

print("Average Revenue per Booking")
print(f"₹ {average_revenue:.2f}")
# Out:
# Average Revenue per Booking
# ₹ 4919.05

# %% [markdown]
# ### Booking Success Rate

# %%
success_rate = metrics.calculate_booking_success_rate()

print("Booking Success Rate")
print(f"{success_rate:.2f}%")
# Out:
# Booking Success Rate
# 84.00%

# %% [markdown]
# ### Occupancy Rate

# %%
occupancy_rate = metrics.calculate_occupancy_rate()

print("Occupancy Rate")
print(f"{occupancy_rate:.2f}%")
# Out:
# Occupancy Rate
# 87.50%

# %% [markdown]
# ## Summary
#
# The following business KPIs were successfully calculated:
#
# - Total Revenue
# - Average Revenue per Booking
# - Booking Success Rate
# - Occupancy Rate
#
# These metrics provide insights into the performance of the pricing strategy and support business decision-making.
